# %% [markdown]
# ## Multi-Class Classification
#
# take clustered data, classify

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__
# Out:
# '3.0.4'

# %%
clustered = pd.read_csv('clustered/clustered_kmeans _2023-08-14 09:31:34.csv')
clustered
# Out:
#       Unnamed: 0  group          time   s_MP    change   type  length  \
# 0              0      1  1.660222e+12  29.99  0.317588  surge       1
# 1              1      3  1.660222e+12  29.85  0.000469  surge       1
# 2              2      5  1.660222e+12  29.87  0.001105  surge       2
# 3              3      7  1.660222e+12  29.89  0.001610  surge       1
# 4              4      9  1.660223e+12  29.90  0.001372  surge       1
# ...          ...    ...           ...    ...       ...    ...     ...
# 5566        5566  11133  1.691438e+12  12.43  0.000805  surge       3
# 5567        5567  11135  1.691441e+12  12.43  0.001530  surge       1
# 5568        5568  11137  1.691442e+12  12.44  0.000564  surge       1
# 5569        5569  11139  1.691443e+12  12.41  0.002981  surge       1
# 5570        5570  11141  1.691445e+12  12.43  0.002744  surge       1
#
#       sum_change    s_area  surge_area  ...     p_type   p_MP   p_buyCap  \
# 0       0.317588  0.317588    0.317588  ...  precursor  30.00  7349599.5
# 1       0.000469  0.000469    0.000469  ...  precursor  29.90  7307990.0
# 2       0.001607  0.003214    0.003214  ...  precursor  29.92  7285245.0
# 3       0.001610  0.001610    0.001610  ...  precursor  29.88  7318707.0
# 4       0.001372  0.001372    0.001372  ...  precursor  29.93  7280582.0
# ...          ...       ...         ...  ...        ...    ...        ...
# 5566    0.002010  0.006031    0.006031  ...  precursor  12.45  1230808.2
# 5567    0.001530  0.001530    0.001530  ...  precursor  12.45  1239702.0
# 5568    0.000564  0.000564    0.000564  ...  precursor  12.43  1210140.5
# 5569    0.002981  0.002981    0.002981  ...  precursor  12.46  1227623.8
# 5570    0.002744  0.002744    0.002744  ...        NaN    NaN        NaN
#
#           p_askCap  p_totalBidVol  p_totalAskVol  p_length  p_sum_change  \
# 0     1.229796e+09      716681.94      314676.40       6.0     -0.004943
# 1     1.229792e+09      715352.90      314642.84       1.0      0.000402
# 2     1.229754e+09      714476.10      313576.00       4.0     -0.002773
# 3     1.229744e+09      715730.56      313546.60       2.0     -0.000200
# 4     1.229794e+09      714140.10      314889.38       7.0     -0.013670
# ...            ...            ...            ...       ...           ...
# 5566  1.275139e+07      305097.16      250228.95       8.0     -0.002408
# 5567  1.274492e+07      305865.50      249742.61       1.0     -0.000401
# 5568  1.275866e+07      303521.28      250877.56       2.0     -0.002653
# 5569  1.274296e+07      304847.25      249542.22       1.0     -0.000720
# 5570           NaN            NaN            NaN       NaN           NaN
#
#         p_area    Cluster
# 0    -0.029656  Cluster 2
# 1     0.000402  Cluster 2
# 2    -0.011090  Cluster 2
# 3    -0.000400  Cluster 2
# 4    -0.095690  Cluster 2
# ...        ...        ...
# 5566 -0.019265  Cluster 3
# 5567 -0.000401  Cluster 3
# 5568 -0.005306  Cluster 3
# 5569 -0.000720  Cluster 3
# 5570       NaN  Cluster 1
#
# [5571 rows x 23 columns]

# %%
clustered.drop(['group', 'time', 's_MP', 'change', 'type', 'length', 'sum_change', 's_area', 'surge_area' ] , axis=1, inplace=True) 
clustered
# Out:
#       Unnamed: 0  p_group        p_time  p_change     p_type   p_MP  \
# 0              0      2.0  1.660222e+12 -0.000467  precursor  30.00
# 1              1      4.0  1.660222e+12  0.000402  precursor  29.90
# 2              2      6.0  1.660222e+12 -0.000066  precursor  29.92
# 3              3      8.0  1.660222e+12 -0.000435  precursor  29.88
# 4              4     10.0  1.660223e+12 -0.000534  precursor  29.93
# ...          ...      ...           ...       ...        ...    ...
# 5566        5566  11134.0  1.691438e+12 -0.000321  precursor  12.45
# 5567        5567  11136.0  1.691441e+12 -0.000401  precursor  12.45
# 5568        5568  11138.0  1.691442e+12 -0.001848  precursor  12.43
# 5569        5569  11140.0  1.691444e+12 -0.000720  precursor  12.46
# 5570        5570      NaN           NaN       NaN        NaN    NaN
#
#        p_buyCap      p_askCap  p_totalBidVol  p_totalAskVol  p_length  \
# 0     7349599.5  1.229796e+09      716681.94      314676.40       6.0
# 1     7307990.0  1.229792e+09      715352.90      314642.84       1.0
# 2     7285245.0  1.229754e+09      714476.10      313576.00       4.0
# 3     7318707.0  1.229744e+09      715730.56      313546.60       2.0
# 4     7280582.0  1.229794e+09      714140.10      314889.38       7.0
# ...         ...           ...            ...            ...       ...
# 5566  1230808.2  1.275139e+07      305097.16      250228.95       8.0
# 5567  1239702.0  1.274492e+07      305865.50      249742.61       1.0
# 5568  1210140.5  1.275866e+07      303521.28      250877.56       2.0
# 5569  1227623.8  1.274296e+07      304847.25      249542.22       1.0
# 5570        NaN           NaN            NaN            NaN       NaN
#
#       p_sum_change    p_area    Cluster
# 0        -0.004943 -0.029656  Cluster 2
# 1         0.000402  0.000402  Cluster 2
# 2        -0.002773 -0.011090  Cluster 2
# 3        -0.000200 -0.000400  Cluster 2
# 4        -0.013670 -0.095690  Cluster 2
# ...            ...       ...        ...
# 5566     -0.002408 -0.019265  Cluster 3
# 5567     -0.000401 -0.000401  Cluster 3
# 5568     -0.002653 -0.005306  Cluster 3
# 5569     -0.000720 -0.000720  Cluster 3
# 5570           NaN       NaN  Cluster 1
#
# [5571 rows x 14 columns]

# %%
#setup 
from pycaret.classification import *
s = setup(clustered, target = 'Cluster', session_id = 42)
# Out:
# <style type="text/css">
# #T_e46d3_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e46d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e46d3_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e46d3_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e46d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e46d3_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e46d3_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e46d3_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e46d3_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e46d3_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e46d3_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e46d3_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_e46d3_row3_col1" class="data row3 col1" >Cluster 0: 0, Cluster 1: 1, Cluster 2: 2, Cluster 3: 3</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e46d3_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_e46d3_row4_col1" class="data row4 col1" >(5571, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e46d3_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_e46d3_row5_col1" class="data row5 col1" >(5571, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e46d3_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_e46d3_row6_col1" class="data row6 col1" >(3899, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e46d3_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_e46d3_row7_col1" class="data row7 col1" >(1672, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e46d3_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e46d3_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e46d3_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_e46d3_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e46d3_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_e46d3_row10_col1" class="data row10 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e46d3_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_e46d3_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e46d3_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_e46d3_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e46d3_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_e46d3_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e46d3_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_e46d3_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e46d3_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_e46d3_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e46d3_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_e46d3_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e46d3_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_e46d3_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e46d3_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_e46d3_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e46d3_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_e46d3_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e46d3_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_e46d3_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e46d3_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_e46d3_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e46d3_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_e46d3_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e46d3_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e46d3_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_e46d3_row23_col1" class="data row23 col1" >c87f</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
exp.setup(clustered, target = 'Cluster', session_id = 42)
# Out:
# <style type="text/css">
# #T_66579_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_66579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66579_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_66579_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66579_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_66579_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_66579_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_66579_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_66579_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_66579_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_66579_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_66579_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_66579_row3_col1" class="data row3 col1" >Cluster 0: 0, Cluster 1: 1, Cluster 2: 2, Cluster 3: 3</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_66579_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_66579_row4_col1" class="data row4 col1" >(5571, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_66579_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_66579_row5_col1" class="data row5 col1" >(5571, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_66579_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_66579_row6_col1" class="data row6 col1" >(3899, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_66579_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_66579_row7_col1" class="data row7 col1" >(1672, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_66579_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_66579_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_66579_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_66579_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_66579_row10_col0" class="data row10 col0" >Rows with missing values</td>
#       <td id="T_66579_row10_col1" class="data row10 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_66579_row11_col0" class="data row11 col0" >Preprocess</td>
#       <td id="T_66579_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_66579_row12_col0" class="data row12 col0" >Imputation type</td>
#       <td id="T_66579_row12_col1" class="data row12 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_66579_row13_col0" class="data row13 col0" >Numeric imputation</td>
#       <td id="T_66579_row13_col1" class="data row13 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_66579_row14_col0" class="data row14 col0" >Categorical imputation</td>
#       <td id="T_66579_row14_col1" class="data row14 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_66579_row15_col0" class="data row15 col0" >Maximum one-hot encoding</td>
#       <td id="T_66579_row15_col1" class="data row15 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_66579_row16_col0" class="data row16 col0" >Encoding method</td>
#       <td id="T_66579_row16_col1" class="data row16 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_66579_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_66579_row17_col1" class="data row17 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_66579_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_66579_row18_col1" class="data row18 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_66579_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_66579_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_66579_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_66579_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_66579_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_66579_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_66579_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_66579_row22_col1" class="data row22 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_66579_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_66579_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_66579_row23_col1" class="data row23 col1" >09b8</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_480fc th {
#   text-align: left;
# }
# #T_480fc_row0_col0, #T_480fc_row0_col2, #T_480fc_row1_col0, #T_480fc_row1_col1, #T_480fc_row1_col3, #T_480fc_row1_col4, #T_480fc_row1_col5, #T_480fc_row1_col6, #T_480fc_row1_col7, #T_480fc_row2_col0, #T_480fc_row2_col1, #T_480fc_row2_col3, #T_480fc_row2_col4, #T_480fc_row2_col5, #T_480fc_row2_col6, #T_480fc_row2_col7, #T_480fc_row3_col0, #T_480fc_row3_col1, #T_480fc_row3_col2, #T_480fc_row3_col3, #T_480fc_row3_col4, #T_480fc_row3_col5, #T_480fc_row3_col6, #T_480fc_row3_col7, #T_480fc_row4_col0, #T_480fc_row4_col1, #T_480fc_row4_col2, #T_480fc_row4_col3, #T_480fc_row4_col4, #T_480fc_row4_col5, #T_480fc_row4_col6, #T_480fc_row4_col7, #T_480fc_row5_col0, #T_480fc_row5_col1, #T_480fc_row5_col2, #T_480fc_row5_col3, #T_480fc_row5_col4, #T_480fc_row5_col5, #T_480fc_row5_col6, #T_480fc_row5_col7, #T_480fc_row6_col0, #T_480fc_row6_col1, #T_480fc_row6_col2, #T_480fc_row6_col3, #T_480fc_row6_col4, #T_480fc_row6_col5, #T_480fc_row6_col6, #T_480fc_row6_col7, #T_480fc_row7_col0, #T_480fc_row7_col1, #T_480fc_row7_col2, #T_480fc_row7_col3, #T_480fc_row7_col4, #T_480fc_row7_col5, #T_480fc_row7_col6, #T_480fc_row7_col7, #T_480fc_row8_col0, #T_480fc_row8_col1, #T_480fc_row8_col2, #T_480fc_row8_col3, #T_480fc_row8_col4, #T_480fc_row8_col5, #T_480fc_row8_col6, #T_480fc_row8_col7, #T_480fc_row9_col0, #T_480fc_row9_col1, #T_480fc_row9_col2, #T_480fc_row9_col3, #T_480fc_row9_col4, #T_480fc_row9_col5, #T_480fc_row9_col6, #T_480fc_row9_col7, #T_480fc_row10_col0, #T_480fc_row10_col1, #T_480fc_row10_col2, #T_480fc_row10_col3, #T_480fc_row10_col4, #T_480fc_row10_col5, #T_480fc_row10_col6, #T_480fc_row10_col7, #T_480fc_row11_col0, #T_480fc_row11_col1, #T_480fc_row11_col2, #T_480fc_row11_col3, #T_480fc_row11_col4, #T_480fc_row11_col5, #T_480fc_row11_col6, #T_480fc_row11_col7, #T_480fc_row12_col0, #T_480fc_row12_col1, #T_480fc_row12_col2, #T_480fc_row12_col3, #T_480fc_row12_col4, #T_480fc_row12_col5, #T_480fc_row12_col6, #T_480fc_row12_col7, #T_480fc_row13_col0, #T_480fc_row13_col1, #T_480fc_row13_col2, #T_480fc_row13_col3, #T_480fc_row13_col4, #T_480fc_row13_col5, #T_480fc_row13_col6, #T_480fc_row13_col7 {
#   text-align: left;
# }
# #T_480fc_row0_col1, #T_480fc_row0_col3, #T_480fc_row0_col4, #T_480fc_row0_col5, #T_480fc_row0_col6, #T_480fc_row0_col7, #T_480fc_row1_col2, #T_480fc_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_480fc_row0_col8, #T_480fc_row1_col8, #T_480fc_row2_col8, #T_480fc_row3_col8, #T_480fc_row4_col8, #T_480fc_row5_col8, #T_480fc_row6_col8, #T_480fc_row7_col8, #T_480fc_row9_col8, #T_480fc_row10_col8, #T_480fc_row11_col8, #T_480fc_row12_col8, #T_480fc_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_480fc_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_480fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_480fc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_480fc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_480fc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_480fc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_480fc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_480fc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_480fc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_480fc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_480fc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_480fc_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_480fc_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_480fc_row0_col1" class="data row0 col1" >0.9995</td>
#       <td id="T_480fc_row0_col2" class="data row0 col2" >0.9998</td>
#       <td id="T_480fc_row0_col3" class="data row0 col3" >0.9995</td>
#       <td id="T_480fc_row0_col4" class="data row0 col4" >0.9995</td>
#       <td id="T_480fc_row0_col5" class="data row0 col5" >0.9995</td>
#       <td id="T_480fc_row0_col6" class="data row0 col6" >0.9993</td>
#       <td id="T_480fc_row0_col7" class="data row0 col7" >0.9993</td>
#       <td id="T_480fc_row0_col8" class="data row0 col8" >0.1460</td>
#     </tr>
#     <tr>
#       <th id="T_480fc_level0_row1" class="row_heading level0 row1" >rf</th>
#       <td id="T_480fc_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#       <td id="T_480fc_row1_col1" class="data row1 col1" >0.9992</td>
#       <td id="T_480fc_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_480fc_row1_col3" class="data row1 col3" >0.9992</td>
#       <td id="T_480fc_row1_col4" class="data row1 col4" >0.9992</td>
#       <td id="T_480fc_row1_col5" class="data row1 col5" >0.9992</td>
#       <td id="T_480fc_row1_col6" class="data row1 col6" >0.9990</td>
#       <td id="T_480fc_row1_col7" class="data row1 col7" >0.9990</td>
#       <td id="T_480fc_row1_col8" class="data row1 col8" >0.4370</td>
#     </tr>
#     <tr>
#       <th id="T_480fc_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_480fc_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_480fc_row2_col1" class="data row2 col1" >0.9992</td>
#       <td id="T_480fc_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_480fc_row2_col3" class="data row2 col3" >0.9992</td>
#       <td id="T_480fc_row2_col4" class="data row2 col4" >0.9992</td>
#       <td id="T_480fc_row2_col5" class="data row2 col5" >0.9992</td>
#       <td id="T_480fc_row2_col6" class="data row2 col6" >0.9990</td>
#       <td id="T_480fc_row2_col7" class="data row2 col7" >0.9990</td>
#       <td id="T_480fc_row2_col8" class="data row2 col8" >0.4070</td>
#     </tr>
#     <tr>
#       <th id="T_480fc_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_480fc_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_480fc_row3_col1" class="data row3 col1" >0.9990</td>
#       <td id="T_480fc_row3_col2" class="data row3 col2" >0.9993</td>
#       <td id="T_480fc_row3_col3" class="data row3 col3" >0.9990</td>
#       <td id="T_480fc_row3_col4" class="data row3 col4" >0.9990</td>
#       <td id="T_480fc_row3_col5" class="data row3 col5" >0.9990</td>
#       <td id="T_480fc_row3_col6" class="data row3 col6" >0.9986</td>
#       <td id="T_480fc_row3_col7" class="data row3 col7" >0.9986</td>
#       <td id="T_480fc_row3_col8" class="data row3 col8" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_480fc_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_480fc_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_480fc_row4_col1" class="data row4 col1" >0.9990</td>
#       <td id="T_480fc_row4_col2" class="data row4 col2" >0.9994</td>
#       <td id="T_480fc_row4_col3" class="data row4 col3" >0.9990</td>
#       <td id="T_480fc_row4_col4" class="data row4 col4" >0.9990</td>
#       <td id="T_480fc_row4_col5" class="data row4 col5" >0.9990</td>
#       <td id="T_480fc_row4_col6" class="data row4 col6" >0.9986</td>
#       <td id="T_480fc_row4_col7" class="data row4 col7" >0.9986</td>
#       <td id="T_480fc_row4_col8" class="data row4 col8" >2.0550</td>
#     </tr>
#     <tr>
#       <th id="T_480fc_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_480fc_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_480fc_row5_col1" class="data row5 col1" >0.9985</td>
#       <td id="T_480fc_row5_col2" class="data row5 col2" >0.9999</td>
#       <td id="T_480fc_row5_col3" class="data row5 col3" >0.9985</td>
#       <td id="T_480fc_row5_col4" class="data row5 col4" >0.9985</td>
#       <td id="T_480fc_row5_col5" class="data row5 col5" >0.9985</td>
#       <td id="T_480fc_row5_col6" class="data row5 col6" >0.9979</td>
#       <td id="T_480fc_row5_col7" class="data row5 col7" >0.9979</td>

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
plot_model(best, plot = 'auc')

# %%
# plot_model(best, plot = 'efficiency')
# #

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
holdout_pred = predict_model(best)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1a13f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a13f_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1a13f_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_1a13f_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_1a13f_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_1a13f_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_1a13f_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_1a13f_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_1a13f_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a13f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1a13f_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_1a13f_row0_col1" class="data row0 col1" >0.9994</td>
#       <td id="T_1a13f_row0_col2" class="data row0 col2" >0.9996</td>
#       <td id="T_1a13f_row0_col3" class="data row0 col3" >0.9994</td>
#       <td id="T_1a13f_row0_col4" class="data row0 col4" >0.9994</td>
#       <td id="T_1a13f_row0_col5" class="data row0 col5" >0.9994</td>
#       <td id="T_1a13f_row0_col6" class="data row0 col6" >0.9992</td>
#       <td id="T_1a13f_row0_col7" class="data row0 col7" >0.9992</td>
#     </tr>
#   </tbody>
# </table>

# %%
holdout_pred.head()
# Out:
#       Unnamed: 0  p_group        p_time  p_change     p_type       p_MP  \
# 4954        4954   9910.0  1.687970e+12 -0.004686  precursor  12.770000
# 2131        2131   4264.0  1.671043e+12 -0.000283  precursor  14.110000
# 5260        5260  10522.0  1.689705e+12 -0.000286  precursor  14.000000
# 1373        1373   2748.0  1.667287e+12 -0.000615  precursor  19.440001
# 3417        3417   6836.0  1.678079e+12 -0.005420  precursor  15.980000
#
#          p_buyCap      p_askCap  p_totalBidVol  p_totalAskVol  p_length  \
# 4954  1406650.375  1.230255e+07   320883.59375  326178.718750       4.0
# 2131  5572677.000  1.131250e+07   716330.37500  222041.468750       4.0
# 5260  1476289.625  1.232563e+07   354022.71875  261870.234375       5.0
# 1373  4734718.500  2.209819e+09   613449.43750  241535.093750       2.0
# 3417  3407809.750  3.411899e+07   443226.90625  326164.000000       1.0
#
#       p_sum_change    p_area  Cluster prediction_label  prediction_score
# 4954     -0.018384 -0.073536        3        Cluster 3               1.0
# 2131     -0.033790 -0.135161        0        Cluster 0               1.0
# 5260     -0.001143 -0.005715        3        Cluster 3               1.0
# 1373     -0.003238 -0.006476        2        Cluster 2               1.0
# 3417     -0.005420 -0.005420        1        Cluster 1               1.0

# %% [markdown]
# ### loading a model

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__

# %%
# functional API
# loaded_model = load_model('iforest_pipeline')
# print(loaded_model)

# OOP API
loaded_model = s.load_model('kmeans_pipeline')
print(loaded_model)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Pipeline(memory=FastMemory(location=/tmp/joblib),
#          steps=[('numerical_imputer',
#                  TransformerWrapper(exclude=None,
#                                     include=['group', 'time', 's_MP', 'change',
#                                              'length', 'sum_change', 's_area',
#                                              'surge_area', 'p_group', 'p_time',
#                                              'p_change', 'p_MP', 'p_buyCap',
#                                              'p_askCap', 'p_totalBidVol',
#                                              'p_totalAskVol', 'p_length',
#                                              'p_sum_change', 'p_area'],
#                                     transformer=SimpleImputer(add_...
#                  TransformerWrapper(exclude=None, include=['type', 'p_type'],
#                                     transformer=OneHotEncoder(cols=['type',
#                                                                     'p_type'],
#                                                               drop_invariant=False,
#                                                               handle_missing='return_nan',
#                                                               handle_unknown='value',
#                                                               return_df=True,
#                                                               use_cat_names=True,
#                                                               verbose=0))),
#                 ('trained_model',
#                  KMeans(algorithm='lloyd', copy_x=True, init='k-means++',
#                         max_iter=300, n_clusters=4, n_init='warn',
#                         random_state=42, tol=0.0001, verbose=0))],
#          verbose=False)
