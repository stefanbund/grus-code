# %% [markdown]
# ## Key Causal Signals Appear in Clusters 2 and 3

# %% [markdown]
# each row represents the caused variable and each column represents the causing variable
#
# This function should return a pd.DataFrame of the shape (5, 5), representing the  𝑝
#  -value matrix for all pairwise Granger Causality tests.

# %%
import pycaret
from pycaret.clustering import *
import pandas as pd
import datetime
from pycaret.regression import *
from pycaret.regression import RegressionExperiment

import seaborn as sns

#get most recent clustering element, or specify by name
fn = 'efficiency_metric/2023-08-14 10:37:50.csv'
ec = pd.read_csv(fn)
ec.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  group          time   s_MP    change   type  \
# 0             0           0      1  1.660222e+12  29.99  0.317588  surge
# 1             1           1      3  1.660222e+12  29.85  0.000469  surge
# 2             2           2      5  1.660222e+12  29.87  0.001105  surge
# 3             3           3      7  1.660222e+12  29.89  0.001610  surge
# 4             4           4      9  1.660223e+12  29.90  0.001372  surge
#
#    length  sum_change    s_area  ...   p_MP   p_buyCap      p_askCap  \
# 0       1    0.317588  0.317588  ...  30.00  7349599.5  1.229796e+09
# 1       1    0.000469  0.000469  ...  29.90  7307990.0  1.229792e+09
# 2       2    0.001607  0.003214  ...  29.92  7285245.0  1.229754e+09
# 3       1    0.001610  0.001610  ...  29.88  7318707.0  1.229744e+09
# 4       1    0.001372  0.001372  ...  29.93  7280582.0  1.229794e+09
#
#    p_totalBidVol p_totalAskVol  p_length  p_sum_change    p_area    Cluster  \
# 0      716681.94     314676.40       6.0     -0.004943 -0.029656  Cluster 2
# 1      715352.90     314642.84       1.0      0.000402  0.000402  Cluster 2
# 2      714476.10     313576.00       4.0     -0.002773 -0.011090  Cluster 2
# 3      715730.56     313546.60       2.0     -0.000200 -0.000400  Cluster 2
# 4      714140.10     314889.38       7.0     -0.013670 -0.095690  Cluster 2
#
#    efficiency
# 0       3.25%
# 1       3.25%
# 2       3.25%
# 3       3.25%
# 4       3.25%
#
# [5 rows x 25 columns]

# %%
ec.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'group', 'time', 's_MP', 'change', 'type',
#        'length', 'sum_change', 's_area', 'surge_area', 'p_group', 'p_time',
#        'p_change', 'p_type', 'p_MP', 'p_buyCap', 'p_askCap', 'p_totalBidVol',
#        'p_totalAskVol', 'p_length', 'p_sum_change', 'p_area', 'Cluster',
#        'efficiency'],
#       dtype='object')

# %%
from statsmodels.tsa.api import VAR
from statsmodels.tsa.vector_ar.var_model import VARResults, VARResultsWrapper

def test_granger(df, p):
    """
    Fits a VAR(p) model on the input df and performs pairwise Granger Causality tests
    """
     # Fit VAR model on first-order differences
    model = VAR(df.diff().dropna())
    results = model.fit(p)
    
    # Initialize p-value matrix
    p_matrix = pd.DataFrame(index=df.columns, columns=df.columns)
    
    # Perform pairwise Granger Causality tests
    for caused in df.columns:
        for causing in df.columns:
            if caused != causing:
                test_result = results.test_causality(caused, causing)
                p_value = test_result.pvalue
                p_matrix.loc[caused, causing] = p_value
    # Ensure all columns have float dtype
    p_matrix = p_matrix.astype(float)
    return p_matrix

# Load data
p=7
setx=['p_MP', 'p_change', 'p_buyCap', 'p_askCap', 'p_totalBidVol','p_totalAskVol',]

# %% [markdown]
# ## Cluster 0 GC

# %%
sendit0 = ec[ec['Cluster']=='Cluster 0'][setx]
p_matrix0 = test_granger(sendit0, p)
# p_matrix0
caul_mtrx = p_matrix0.rename(index={item: f"{item} caused by" for item in p_matrix0.index})
caul_mtrx.where(caul_mtrx.isna(), caul_mtrx <= 0.01)
# Out:
#                           p_MP p_change p_buyCap p_askCap p_totalBidVol  \
# p_MP caused by             NaN    False    False    False         False
# p_change caused by       False      NaN    False    False         False
# p_buyCap caused by       False    False      NaN    False         False
# p_askCap caused by       False    False    False      NaN         False
# p_totalBidVol caused by  False    False    False    False           NaN
# p_totalAskVol caused by  False    False    False    False         False
#
#                         p_totalAskVol
# p_MP caused by                  False
# p_change caused by              False
# p_buyCap caused by              False
# p_askCap caused by              False
# p_totalBidVol caused by         False
# p_totalAskVol caused by           NaN

# %% [markdown]
# ## Cluster 1

# %%
sendit1 = ec[ec['Cluster']=='Cluster 1'][setx]
p_matrix1 = test_granger(sendit1, p)
# p_matrix0
caul_mtrx1 = p_matrix1.rename(index={item: f"{item} caused by" for item in p_matrix1.index})
caul_mtrx1.where(caul_mtrx1.isna(), caul_mtrx1 <= 0.01)
# Out:
#                           p_MP p_change p_buyCap p_askCap p_totalBidVol  \
# p_MP caused by             NaN    False    False    False         False
# p_change caused by       False      NaN    False    False         False
# p_buyCap caused by       False    False      NaN     True         False
# p_askCap caused by       False    False    False      NaN         False
# p_totalBidVol caused by  False    False    False     True           NaN
# p_totalAskVol caused by  False    False    False    False         False
#
#                         p_totalAskVol
# p_MP caused by                  False
# p_change caused by              False
# p_buyCap caused by               True
# p_askCap caused by              False
# p_totalBidVol caused by          True
# p_totalAskVol caused by           NaN

# %% [markdown]
# ## Cluster 2

# %%
sendit2 = ec[ec['Cluster']=='Cluster 2'][setx]
p_matrix2 = test_granger(sendit2, p)
# p_matrix0
caul_mtrx2 = p_matrix2.rename(index={item: f"{item} caused by" for item in p_matrix2.index})
caul_mtrx2.where(caul_mtrx2.isna(), caul_mtrx2 <= 0.01)
# Out:
#                           p_MP p_change p_buyCap p_askCap p_totalBidVol  \
# p_MP caused by             NaN    False    False    False         False
# p_change caused by       False      NaN    False    False         False
# p_buyCap caused by       False    False      NaN    False         False
# p_askCap caused by       False    False    False      NaN         False
# p_totalBidVol caused by  False    False     True    False           NaN
# p_totalAskVol caused by  False     True    False    False         False
#
#                         p_totalAskVol
# p_MP caused by                  False
# p_change caused by               True
# p_buyCap caused by               True
# p_askCap caused by              False
# p_totalBidVol caused by         False
# p_totalAskVol caused by           NaN

# %%
sns.heatmap(p_matrix2.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Cluster 3: largest space for profitable trades
# (length = duration, height = positive variance)

# %%
sendit3 = ec[ec['Cluster']=='Cluster 3'][setx]
p_matrix3 = test_granger(sendit3, p)
# p_matrix0
caul_mtrx3 = p_matrix3.rename(index={item: f"{item} caused by" for item in p_matrix3.index})
caul_mtrx3.where(caul_mtrx3.isna(), caul_mtrx3 <= 0.01)
# Out:
#                           p_MP p_change p_buyCap p_askCap p_totalBidVol  \
# p_MP caused by             NaN    False    False    False         False
# p_change caused by        True      NaN    False    False         False
# p_buyCap caused by       False    False      NaN    False         False
# p_askCap caused by       False    False    False      NaN         False
# p_totalBidVol caused by  False    False    False    False           NaN
# p_totalAskVol caused by   True    False    False    False         False
#
#                         p_totalAskVol
# p_MP caused by                  False
# p_change caused by              False
# p_buyCap caused by              False
# p_askCap caused by              False
# p_totalBidVol caused by         False
# p_totalAskVol caused by           NaN

# %% [markdown]
# ## Cluster 3 regression study
# highest performing cluster for length x height

# %%
## correlation matrix
p_matrix3.corr()
# Out:
#                    p_MP  p_change  p_buyCap  p_askCap  p_totalBidVol  \
# p_MP           1.000000  0.941454 -0.010788  0.332807       0.819571
# p_change       0.941454  1.000000  0.366811 -0.564463       0.735273
# p_buyCap      -0.010788  0.366811  1.000000 -0.601310       0.819700
# p_askCap       0.332807 -0.564463 -0.601310  1.000000      -0.102884
# p_totalBidVol  0.819571  0.735273  0.819700 -0.102884       1.000000
# p_totalAskVol -0.215800  0.805336  0.463521 -0.866259       0.485567
#
#                p_totalAskVol
# p_MP               -0.215800
# p_change            0.805336
# p_buyCap            0.463521
# p_askCap           -0.866259
# p_totalBidVol       0.485567
# p_totalAskVol       1.000000

# %% [markdown]
# **positively correlated**: p_change / p_MP
#
# **negatively**: p_askCap / p_totalAskVol
#             p_askCap / p_totalAskVol

# %%
sns.heatmap(p_matrix3.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## multi-model regression on surge area
#
# [from](https://github.com/pycaret/pycaret/blob/master/tutorials/Tutorial%20-%20Regression.ipynb)

# %%
s = setup(ec, target = 's_MP', session_id = 42)

exp = RegressionExperiment()

exp.setup(ec, target = 's_MP', session_id = 42)
# Out:
# <style type="text/css">
# #T_177fe_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_177fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_177fe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_177fe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_177fe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_177fe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_177fe_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_177fe_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_177fe_row1_col1" class="data row1 col1" >s_MP</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_177fe_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_177fe_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_177fe_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_177fe_row3_col1" class="data row3 col1" >(5571, 25)</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_177fe_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_177fe_row4_col1" class="data row4 col1" >(5571, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_177fe_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_177fe_row5_col1" class="data row5 col1" >(3899, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_177fe_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_177fe_row6_col1" class="data row6 col1" >(1672, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_177fe_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_177fe_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_177fe_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_177fe_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_177fe_row9_col0" class="data row9 col0" >Rows with missing values</td>
#       <td id="T_177fe_row9_col1" class="data row9 col1" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_177fe_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_177fe_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_177fe_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_177fe_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_177fe_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_177fe_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_177fe_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_177fe_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_177fe_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_177fe_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_177fe_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_177fe_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_177fe_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_177fe_row16_col1" class="data row16 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_177fe_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_177fe_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_177fe_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_177fe_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_177fe_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_177fe_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_177fe_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_177fe_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_177fe_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_177fe_row21_col1" class="data row21 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_177fe_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_177fe_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_177fe_row22_col1" class="data row22 col1" >a934</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0e519_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0e519">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e519_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0e519_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e519_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e519_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0e519_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0e519_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e519_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_
row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e8dd1_row1_col1" class="data row1 col1" >0.0540</td>
#       <td id="T_e8dd1_row1_col2" class="data row1 col2" >0.0136</td>
#       <td id="T_e8dd1_row1_col3" class="data row1 col3" >0.1106</td>
#       <td id="T_e8dd1_row1_col4" class="data row1 col4" >0.9988</td>
#       <td id="T_e8dd1_row1_col5" class="data row1 col5" >0.0063</td>
#       <td id="T_e8dd1_row1_col6" class="data row1 col6" >0.0033</td>
#       <td id="T_e8dd1_row1_col7" class="data row1 col7" >120.4210</td>
#     </tr>
#     <tr>
#       <th id="T_e8dd1_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_e8dd1_row2_col0" class="data row2 col0" >Extra Trees Regressor</td>
#       <td id="T_e8dd1_row2_col1" class="data row2 col1" >0.0530</td>
#       <td id="T_e8dd1_row2_col2" class="data row2 col2" >0.0150</td>
#       <td id="T_e8dd1_row2_col3" class="data row2 col3" >0.1169</td>
#       <td id="T_e8dd1_row2_col4" class="data row2 col4" >0.9987</td>
#       <td id="T_e8dd1_row2_col5" class="data row2 col5" >0.0068</td>
#       <td id="T_e8dd1_row2_col6" class="data row2 col6" >0.0032</td>
#       <td id="T_e8dd1_row2_col7" class="data row2 col7" >0.4320</td>
#     </tr>
#     <tr>
#       <th id="T_e8dd1_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_e8dd1_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_e8dd1_row3_col1" class="data row3 col1" >0.0560</td>
#       <td id="T_e8dd1_row3_col2" class="data row3 col2" >0.0161</td>
#       <td id="T_e8dd1_row3_col3" class="data row3 col3" >0.1224</td>
#       <td id="T_e8dd1_row3_col4" class="data row3 col4" >0.9985</td>
#       <td id="T_e8dd1_row3_col5" class="data row3 col5" >0.0071</td>
#       <td id="T_e8dd1_row3_col6" class="data row3 col6" >0.0034</td>
#       <td id="T_e8dd1_row3_col7" class="data row3 col7" >0.8710</td>
#     </tr>
#     <tr>
#       <th id="T_e8dd1_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_e8dd1_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_e8dd1_row4_col1" class="data row4 col1" >0.0729</td>
#       <td id="T_e8dd1_row4_col2" class="data row4 col2" >0.0242</td>
#       <td id="T_e8dd1_row4_col3" class="data row4 col3" >0.1511</td>
#       <td id="T_e8dd1_row4_col4" class="data row4 col4" >0.9978</td>
#       <td id="T_e8dd1_row4_col5" class="data row4 col5" >0.0088</td>
#       <td id="T_e8dd1_row4_col6" class="data row4 col6" >0.0045</td>
#       <td id="T_e8dd1_row4_col7" class="data row4 col7" >0.0820</td>
#     </tr>
#     <tr>
#       <th id="T_e8dd1_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_e8dd1_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_e8dd1_row5_col1" class="data row5 col1" >0.1156</td>
#       <td id="T_e8dd1_row5_col2" class="data row5 col2" >0.0462</td>
#       <td id="T_e8dd1_row5_col3" class="data row5 col3" >0.2113</td>
#       <td id="T_e8dd1_row5_col4" class="data row5 col4" >0.9958</td>
#       <td id="T_e8dd1_row5_col5" class="data row5 col5" >0.0120</td>
#       <td id="T_e8dd1_row5_col6" class="data row5 col6" >0.0070</td>
#       <td id="T_e8dd1_row5_col7" class="data row5 col7" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_e8dd1_lev

# %%
# plot residuals
plot_model(best, plot = 'residuals')

# %%
# plot error
plot_model(best, plot = 'error')

# %%
# plot feature importance
plot_model(best, plot = 'feature')

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
