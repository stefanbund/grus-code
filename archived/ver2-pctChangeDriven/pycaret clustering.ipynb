# %%
# check installed version
import pycaret
# import pycaret clustering and init setup
from pycaret.clustering import *
import pandas as pd
import datetime
pycaret.__version__
# Out:
# '3.0.4'

# %% [markdown]
# ### ingest and setup

# %%
m2_pipeline = pd.read_csv('pipeline1.csv')

# %%
#change is surge price rate of change per observation, change.1 is precursor
#sum_change is surge sum_change per surge, and surge_area is surge alone
keepable = ['precursor_buy_cap_pct_change', 
            'precursor_ask_cap_pct_change',
            'precursor_bid_vol_pct_change', 
            'precursor_ask_vol_pct_change', 'change.1',
            'surge_targets_met_pct']
m2_pipeline = m2_pipeline[keepable]

# %%
m2_pipeline
# Out:
#       precursor_buy_cap_pct_change  precursor_ask_cap_pct_change  \
# 0                              NaN                           NaN
# 1                        -0.000443                      0.000023
# 2                        -0.002358                     -0.000002
# 3                         0.000349                      0.000031
# 4                         0.000473                      0.000015
# ...                            ...                           ...
# 5632                     -0.008493                     -0.001014
# 5633                     -0.002290                      0.000014
# 5634                     -0.002373                     -0.000333
# 5635                      0.003724                      0.000931
# 5636                     -0.007463                     -0.000010
#
#       precursor_bid_vol_pct_change  precursor_ask_vol_pct_change  change.1  \
# 0                              NaN                           NaN -0.000533
# 1                        -0.000184                      0.003196  0.000135
# 2                        -0.000818                     -0.000333 -0.000233
# 3                         0.000189                      0.004485 -0.000502
# 4                         0.000120                      0.001861 -0.000768
# ...                            ...                           ...       ...
# 5632                     -0.002097                     -0.004181 -0.283913
# 5633                     -0.000566                      0.000067  0.000399
# 5634                     -0.000586                     -0.001572  0.000000
# 5635                      0.000911                      0.004449  0.000000
# 5636                     -0.001816                     -0.000013       NaN
#
#       surge_targets_met_pct
# 0                       NaN
# 1                 -0.033490
# 2                 -0.033445
# 3                 -0.033467
# 4                 -0.167224
# ...                     ...
# 5632               0.000000
# 5633               0.000000
# 5634              -0.099701
# 5635              -0.099800
# 5636              -0.199203
#
# [5637 rows x 6 columns]

# %%
m2_pipeline = m2_pipeline.dropna()
print(m2_pipeline.isna().sum(axis=1).astype(bool).sum())
# Out:
# 0

# %%
m2_pipeline.columns
# Out:
# Index(['precursor_buy_cap_pct_change', 'precursor_ask_cap_pct_change',
#        'precursor_bid_vol_pct_change', 'precursor_ask_vol_pct_change',
#        'change.1', 'surge_targets_met_pct'],
#       dtype='object')

# %%
m2_pipeline.dtypes
# Out:
# precursor_buy_cap_pct_change    float64
# precursor_ask_cap_pct_change    float64
# precursor_bid_vol_pct_change    float64
# precursor_ask_vol_pct_change    float64
# change.1                        float64
# surge_targets_met_pct           float64
# dtype: object

# %%
m2_pipeline = m2_pipeline.astype('float')

# %%
m2_pipeline.dtypes
# Out:
# precursor_buy_cap_pct_change    float64
# precursor_ask_cap_pct_change    float64
# precursor_bid_vol_pct_change    float64
# precursor_ask_vol_pct_change    float64
# change.1                        float64
# surge_targets_met_pct           float64
# dtype: object

# %%
#HOME
s = setup(m2_pipeline, session_id = 42)
# Out:
# <style type="text/css">
# #T_58733_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_58733">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58733_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_58733_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58733_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58733_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_58733_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_58733_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_58733_row1_col1" class="data row1 col1" >(5634, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_58733_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_58733_row2_col1" class="data row2 col1" >(5634, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_58733_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_58733_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_58733_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_58733_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_58733_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_58733_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_58733_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_58733_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_58733_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_58733_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_58733_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_58733_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_58733_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_58733_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_58733_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_58733_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_58733_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_58733_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_58733_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_58733_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_58733_row12_col1" class="data row12 col1" >37bd</td>
#     </tr>
#   </tbody>
# </table>

# %%
# import ClusteringExperiment and init the class
from pycaret.clustering import ClusteringExperiment
exp = ClusteringExperiment()

# %%
# check the type of exp
type(exp)
# Out:
# pycaret.clustering.oop.ClusteringExperiment

# %%
# init setup on exp
exp.setup(m2_pipeline, session_id = 42)
# Out:
# <style type="text/css">
# #T_f382e_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f382e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f382e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f382e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f382e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f382e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f382e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f382e_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_f382e_row1_col1" class="data row1 col1" >(5634, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f382e_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_f382e_row2_col1" class="data row2 col1" >(5634, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f382e_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_f382e_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f382e_row4_col0" class="data row4 col0" >Preprocess</td>
#       <td id="T_f382e_row4_col1" class="data row4 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f382e_row5_col0" class="data row5 col0" >Imputation type</td>
#       <td id="T_f382e_row5_col1" class="data row5 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f382e_row6_col0" class="data row6 col0" >Numeric imputation</td>
#       <td id="T_f382e_row6_col1" class="data row6 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f382e_row7_col0" class="data row7 col0" >Categorical imputation</td>
#       <td id="T_f382e_row7_col1" class="data row7 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f382e_row8_col0" class="data row8 col0" >CPU Jobs</td>
#       <td id="T_f382e_row8_col1" class="data row8 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f382e_row9_col0" class="data row9 col0" >Use GPU</td>
#       <td id="T_f382e_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f382e_row10_col0" class="data row10 col0" >Log Experiment</td>
#       <td id="T_f382e_row10_col1" class="data row10 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f382e_row11_col0" class="data row11 col0" >Experiment Name</td>
#       <td id="T_f382e_row11_col1" class="data row11 col1" >cluster-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f382e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f382e_row12_col0" class="data row12 col0" >USI</td>
#       <td id="T_f382e_row12_col1" class="data row12 col1" >25d6</td>
#     </tr>
#   </tbody>
# </table>

# %%
# to check all the available models
models()
# Out:
#                                        Name  \
# ID
# kmeans                   K-Means Clustering
# ap                     Affinity Propagation
# meanshift             Mean Shift Clustering
# sc                      Spectral Clustering
# hclust             Agglomerative Clustering
# dbscan     Density-Based Spatial Clustering
# optics                    OPTICS Clustering
# birch                      Birch Clustering
#
#                                                    Reference
# ID
# kmeans                        sklearn.cluster._kmeans.KMeans
# ap         sklearn.cluster._affinity_propagation.Affinity...
# meanshift              sklearn.cluster._mean_shift.MeanShift
# sc              sklearn.cluster._spectral.SpectralClustering
# hclust     sklearn.cluster._agglomerative.AgglomerativeCl...
# dbscan                        sklearn.cluster._dbscan.DBSCAN
# optics                        sklearn.cluster._optics.OPTICS
# birch                           sklearn.cluster._birch.Birch

# %% [markdown]
# ### discover optimal clustering, then initiate clustering algo

# %%
# train kmeans model
mtext = 'meanshift'
m = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a4e59">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4e59_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_a4e59_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_a4e59_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_a4e59_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_a4e59_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_a4e59_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4e59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4e59_row0_col0" class="data row0 col0" >0.5060</td>
#       <td id="T_a4e59_row0_col1" class="data row0 col1" >25178.8442</td>
#       <td id="T_a4e59_row0_col2" class="data row0 col2" >0.4990</td>
#       <td id="T_a4e59_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_a4e59_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_a4e59_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext='kmeans'
m2 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0dfc4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dfc4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0dfc4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0dfc4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0dfc4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0dfc4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0dfc4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dfc4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0dfc4_row0_col0" class="data row0 col0" >0.6468</td>
#       <td id="T_0dfc4_row0_col1" class="data row0 col1" >117946.4737</td>
#       <td id="T_0dfc4_row0_col2" class="data row0 col2" >0.4282</td>
#       <td id="T_0dfc4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0dfc4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0dfc4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext='ap'
m3 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b975">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b975_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b975_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b975_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b975_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b975_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b975_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b975_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b975_row0_col0" class="data row0 col0" >0.3279</td>
#       <td id="T_6b975_row0_col1" class="data row0 col1" >100997.2256</td>
#       <td id="T_6b975_row0_col2" class="data row0 col2" >0.9520</td>
#       <td id="T_6b975_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6b975_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6b975_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext = 'sc'
m4= create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_df242">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_df242_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_df242_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_df242_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_df242_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_df242_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_df242_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df242_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df242_row0_col0" class="data row0 col0" >0.8894</td>
#       <td id="T_df242_row0_col1" class="data row0 col1" >20.9385</td>
#       <td id="T_df242_row0_col2" class="data row0 col2" >0.1203</td>
#       <td id="T_df242_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_df242_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_df242_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext = 'hclust'
m5 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fe774">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe774_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fe774_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fe774_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fe774_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fe774_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fe774_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe774_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe774_row0_col0" class="data row0 col0" >0.5545</td>
#       <td id="T_fe774_row0_col1" class="data row0 col1" >102600.0554</td>
#       <td id="T_fe774_row0_col2" class="data row0 col2" >0.4883</td>
#       <td id="T_fe774_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_fe774_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_fe774_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext = 'dbscan'
m6 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_587b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_587b7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_587b7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_587b7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_587b7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_587b7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_587b7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_587b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_587b7_row0_col0" class="data row0 col0" >0.9627</td>
#       <td id="T_587b7_row0_col1" class="data row0 col1" >360.3954</td>
#       <td id="T_587b7_row0_col2" class="data row0 col2" >1.8848</td>
#       <td id="T_587b7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_587b7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_587b7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext = 'optics'
m7 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_04999">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04999_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_04999_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_04999_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_04999_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_04999_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_04999_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04999_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04999_row0_col0" class="data row0 col0" >-0.6003</td>
#       <td id="T_04999_row0_col1" class="data row0 col1" >0.7866</td>
#       <td id="T_04999_row0_col2" class="data row0 col2" >2.0054</td>
#       <td id="T_04999_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_04999_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_04999_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
mtext = 'birch'
m8 = create_model(mtext)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76be0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76be0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_76be0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_76be0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_76be0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_76be0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_76be0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76be0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76be0_row0_col0" class="data row0 col0" >0.8963</td>
#       <td id="T_76be0_row0_col1" class="data row0 col1" >55309.4700</td>
#       <td id="T_76be0_row0_col2" class="data row0 col2" >0.2892</td>
#       <td id="T_76be0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_76be0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_76be0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### assign model

# %%
cluster = assign_model(m4)
model_text = 'sc'
cluster
# Out:
#       precursor_buy_cap_pct_change  precursor_ask_cap_pct_change  \
# 1                        -0.000443                      0.000023
# 2                        -0.002358                     -0.000002
# 3                         0.000349                      0.000031
# 4                         0.000473                      0.000015
# 5                         0.006050                      0.000020
# ...                            ...                           ...
# 5631                      0.000261                     -0.003409
# 5632                     -0.008493                     -0.001014
# 5633                     -0.002290                      0.000014
# 5634                     -0.002373                     -0.000333
# 5635                      0.003724                      0.000931
#
#       precursor_bid_vol_pct_change  precursor_ask_vol_pct_change  change.1  \
# 1                        -0.000184                      0.003196  0.000135
# 2                        -0.000818                     -0.000333 -0.000233
# 3                         0.000189                      0.004485 -0.000502
# 4                         0.000120                      0.001861 -0.000768
# 5                         0.002144                      0.003015 -0.000303
# ...                            ...                           ...       ...
# 5631                      0.000050                     -0.016427 -0.000398
# 5632                     -0.002097                     -0.004181 -0.283913
# 5633                     -0.000566                      0.000067  0.000399
# 5634                     -0.000586                     -0.001572  0.000000
# 5635                      0.000911                      0.004449  0.000000
#
#       surge_targets_met_pct    Cluster
# 1                 -0.033490  Cluster 0
# 2                 -0.033445  Cluster 0
# 3                 -0.033467  Cluster 0
# 4                 -0.167224  Cluster 0
# 5                 -0.371245  Cluster 0
# ...                     ...        ...
# 5631              -0.199005  Cluster 0
# 5632               0.000000  Cluster 0
# 5633               0.000000  Cluster 0
# 5634              -0.099701  Cluster 0
# 5635              -0.099800  Cluster 0
#
# [5634 rows x 7 columns]

# %% [markdown]
# ### push clustered df to csv (Finish pipeline step)

# %%
# plot pca cluster plot 
plot_model(m4, plot = 'cluster')

# %%
# plot elbow, not for ap
# plot_model(m, plot = 'elbow')

# %%
cluster.dtypes
# Out:
# precursor_buy_cap_pct_change    float32
# precursor_ask_cap_pct_change    float32
# precursor_bid_vol_pct_change    float32
# precursor_ask_vol_pct_change    float32
# change.1                        float32
# surge_targets_met_pct           float32
# Cluster                          object
# dtype: object

# %%
#occurences per year
cluster.groupby('Cluster').count()#  _value_counts()
# x = (17 / 5617) * 900
# print(x)
# Out:
#            precursor_buy_cap_pct_change  precursor_ask_cap_pct_change  \
# Cluster
# Cluster 0                          5622                          5622
# Cluster 1                             1                             1
# Cluster 2                            10                            10
# Cluster 3                             1                             1
#
#            precursor_bid_vol_pct_change  precursor_ask_vol_pct_change  \
# Cluster
# Cluster 0                          5622                          5622
# Cluster 1                             1                             1
# Cluster 2                            10                            10
# Cluster 3                             1                             1
#
#            change.1  surge_targets_met_pct
# Cluster
# Cluster 0      5622                   5622
# Cluster 1         1                      1
# Cluster 2        10                     10
# Cluster 3         1                      1

# %%
# plot silhouette
# plot_model(m, plot = 'silhouette')

# %%
evaluate_model(m4)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# # predict on test set

# # m5 = create_model(mtext)
# sc_pred = predict_model(m4, data=m2_pipeline)
# sc_pred
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 4
#       1 # predict on test set
#       2
#       3 # m5 = create_model(mtext)
# ----> 4 sc_pred = predict_model(m4, data=m2_pipeline)
#       5 sc_pred
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/clustering/functional.py:861, in predict_model(model, data)
#     858 if experiment is None:
#     859     experiment = _EXPERIMENT_CLASS()
# --> 861 return experiment.predict_model(
#     862     estimator=model,
#     863     data=data,
#     864 )
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/clustering/oop.py:94, in ClusteringExperiment.predict_model(self, estimator, data, ml_usecase)
#      53 def predict_model(
#      54     self, estimator, data: pd.DataFrame, ml_usecase: Optional[MLUsecase] = None
#      55 ) -> pd.DataFrame:
#      56     """
#      57     This function generates cluster labels using a trained model.
#      58
#    (...)
#      91
#      92     """
# ---> 94     return super().predict_model(estimator, data, ml_usecase)
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/unsupervised_experiment.py:890, in _UnsupervisedExperiment.predict_model(self, estimator, data, ml_usecase)
#     888     pass
#     889 else:
# --> 890     raise TypeError("Model doesn't have the predict method.")
#     892 output = data.copy()
#     893 pred = estimator.predict(data)
#
# TypeError: Model doesn't have the predict method.

# %% [markdown]
# ### eliminate rows with cluster membership under two, for step3 purposes

# %%
# # Group the DataFrame by the Cluster column
# grouped = sc_pred.groupby('Cluster')

# # Filter out rows that belong to only one cluster
# filtered = grouped.filter(lambda x: len(x) > 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 2
#       1 # Group the DataFrame by the Cluster column
# ----> 2 grouped = sc_pred.groupby('Cluster')
#       4 # Filter out rows that belong to only one cluster
#       5 filtered = grouped.filter(lambda x: len(x) > 1)
#
# NameError: name 'sc_pred' is not defined

# %%
# filtered.columns

# %%
# Group the DataFrame by the Cluster column
grouped = cluster.groupby('Cluster')

# Filter out rows that belong to only one cluster
filtered = grouped.filter(lambda x: len(x) > 1)

# %%
now = datetime.datetime.now()
print("Current date and time: ")
print(now.strftime("%Y-%m-%d %H:%M:%S"))

model_type = model_text  #from above cell
run_time = now.strftime("%Y-%m-%d %H:%M:%S")
file_name = 'clustered/'+ 'clustered_'+ model_type+' _'+ run_time+ '.csv'
print(file_name)
filtered.to_csv(file_name)
# Out:
# Current date and time:
# 2023-09-09 19:45:53
# clustered/clustered_sc _2023-09-09 19:45:53.csv
