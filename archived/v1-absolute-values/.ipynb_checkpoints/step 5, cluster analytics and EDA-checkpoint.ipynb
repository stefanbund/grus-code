# %% [markdown]
# ## vanilla pycaret EDA on clustered data

# %%
import pycaret
from pycaret.clustering import *
import pandas as pd
import datetime

#get most recent clustering element, or specify by name
fn = 'clustered/clustered_kmeans _2023-08-14 09:31:34.csv'
cluster = pd.read_csv(fn)
cluster.head()
# Out:
#    Unnamed: 0  group          time   s_MP    change   type  length  \
# 0           0      1  1.660222e+12  29.99  0.317588  surge       1
# 1           1      3  1.660222e+12  29.85  0.000469  surge       1
# 2           2      5  1.660222e+12  29.87  0.001105  surge       2
# 3           3      7  1.660222e+12  29.89  0.001610  surge       1
# 4           4      9  1.660223e+12  29.90  0.001372  surge       1
#
#    sum_change    s_area  surge_area  ...     p_type   p_MP   p_buyCap  \
# 0    0.317588  0.317588    0.317588  ...  precursor  30.00  7349599.5
# 1    0.000469  0.000469    0.000469  ...  precursor  29.90  7307990.0
# 2    0.001607  0.003214    0.003214  ...  precursor  29.92  7285245.0
# 3    0.001610  0.001610    0.001610  ...  precursor  29.88  7318707.0
# 4    0.001372  0.001372    0.001372  ...  precursor  29.93  7280582.0
#
#        p_askCap  p_totalBidVol  p_totalAskVol  p_length  p_sum_change  \
# 0  1.229796e+09      716681.94      314676.40       6.0     -0.004943
# 1  1.229792e+09      715352.90      314642.84       1.0      0.000402
# 2  1.229754e+09      714476.10      313576.00       4.0     -0.002773
# 3  1.229744e+09      715730.56      313546.60       2.0     -0.000200
# 4  1.229794e+09      714140.10      314889.38       7.0     -0.013670
#
#      p_area    Cluster
# 0 -0.029656  Cluster 2
# 1  0.000402  Cluster 2
# 2 -0.011090  Cluster 2
# 3 -0.000400  Cluster 2
# 4 -0.095690  Cluster 2
#
# [5 rows x 23 columns]

# %%
cluster.columns
# Out:
# Index(['Unnamed: 0', 'group', 'time', 's_MP', 'change', 'type', 'length',
#        'sum_change', 's_area', 'surge_area', 'p_group', 'p_time', 'p_change',
#        'p_type', 'p_MP', 'p_buyCap', 'p_askCap', 'p_totalBidVol',
#        'p_totalAskVol', 'p_length', 'p_sum_change', 'p_area', 'Cluster'],
#       dtype='object')

# %%
s = setup(cluster, target = 'Cluster', session_id = 42)

# generate EDA
eda()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s = setup(cluster, target = 'Cluster', session_id = 42)
#       3 # generate EDA
#       4 eda()
#
# TypeError: setup() got an unexpected keyword argument 'target'

# %%
# load dataset
from pycaret.datasets import get_data
data = get_data('iris')
print(type(data))
# init setup
from pycaret.classification import *
s = setup(data, target = 'species', session_id = 123)

# generate EDA
eda()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# <class 'pandas.core.frame.DataFrame'>
# <style type="text/css">
# #T_4a79c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4a79c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a79c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4a79c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a79c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a79c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4a79c_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a79c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4a79c_row1_col1" class="data row1 col1" >species</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a79c_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_4a79c_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a79c_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_4a79c_row3_col1" class="data row3 col1" >Iris-setosa: 0, Iris-versicolor: 1, Iris-virginica: 2</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a79c_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_4a79c_row4_col1" class="data row4 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a79c_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_4a79c_row5_col1" class="data row5 col1" >(150, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_4a79c_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_4a79c_row6_col1" class="data row6 col1" >(105, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_4a79c_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_4a79c_row7_col1" class="data row7 col1" >(45, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_4a79c_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_4a79c_row8_col1" class="data row8 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_4a79c_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_4a79c_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_4a79c_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_4a79c_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_4a79c_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_4a79c_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_4a79c_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_4a79c_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_4a79c_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_4a79c_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_4a79c_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_4a79c_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_4a79c_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_4a79c_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_4a79c_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_4a79c_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_4a79c_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_4a79c_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_4a79c_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_4a79c_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_4a79c_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_4a79c_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_4a79c_row19_col1" class="data row19 col1" >9ba2</td>
#     </tr>
#   </tbody>
# </table>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 10
#       7 s = setup(data, target = 'species', session_id = 123)
#       9 # generate EDA
# ---> 10 eda()
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/utils/generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/classification/functional.py:3090, in eda(display_format, **kwargs)
#    3062 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    3063 def eda(display_format: str = "bokeh", **kwargs):
#    3064     """
#    3065     This function generates AutoEDA using AutoVIZ library. You must
#    3066     install Autoviz separately ``pip install autoviz`` to use this
#    (...)
#    3088         None
#    3089     """
# -> 3090     return _CURRENT_EXPERIMENT.eda(display_format=display_format, **kwargs)
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:2641, in _TabularExperiment.eda(self, display_format, **kwargs)
#    2613 def eda(self, display_format: str = "bokeh", **kwargs):
#    2614     """
#    2615     This function generates AutoEDA using AutoVIZ library. You must
#    2616     install Autoviz separately ``pip install autoviz`` to use this
#    (...)
#    2638         None
#    2639     """
# -> 2641     _check_soft_dependencies("autoviz", extra="mlops", severity="error")
#    2642     from autoviz.AutoViz_Class import AutoViz_Class
#    2644     AV = AutoViz_Class()
#
# File ~/Desktop/GRUS/caret1/lib/python3.8/site-packages/pycaret/utils/_dependencies.py:152, in _check_soft_dependencies(package, severity, extra, install_name)
#     150 if severity == "error":
#     151     logger.exception(f"{msg}")
# --> 152     raise ModuleNotFoundError(msg)
#     153 elif severity == "warning":
#     154     logger.warning(f"{msg}")
#
# ModuleNotFoundError:
# 'autoviz' is a soft dependency and not included in the pycaret installation. Please run: `pip install autoviz` to install.
# Alternately, you can install this by running `pip install pycaret[mlops]`
