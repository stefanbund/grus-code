# %% [markdown]
# ## Multi-Class Classification
#
# take clustered data, classify

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__
# Out:
# '3.0.4'

# %%
clustered = pd.read_csv('clustered/clustered_meanshift _2023-09-04 14:54:24.csv')
clustered
# Out:
#       Unnamed: 0  precursor_buy_cap_pct_change  precursor_ask_cap_pct_change  \
# 0              0                     -0.000618                     -0.000017
# 1              1                     -0.002358                     -0.000002
# 2              2                      0.004750                     -0.000036
# 3              3                     -0.000987                      0.000002
# 4              4                      0.001531                      0.000010
# ...          ...                           ...                           ...
# 5573        5630                      0.000251                      0.003062
# 5574        5631                      0.000555                      0.000699
# 5575        5633                      0.004809                      0.000779
# 5576        5634                     -0.000989                     -0.000484
# 5577        5635                      0.006274                     -0.001249
#
# ...

# %%
# clustered.drop(['group', 'time', 's_MP', 'change', 'type', 'length', 'sum_change', 'surge_area' ] , axis=1, inplace=True) 
print(clustered.columns)
# Out:
# Index(['Unnamed: 0', 'precursor_buy_cap_pct_change',
#        'precursor_ask_cap_pct_change', 'precursor_bid_vol_pct_change',
#        'precursor_ask_vol_pct_change', 'change.1', 'sum_change.1', 'Cluster'],
#       dtype='object')

# %%
#setup 
from pycaret.classification import *
s = setup(clustered, target = 'Cluster', session_id = 42)
# Out:
# <style type="text/css">
# #T_5683c_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_5683c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5683c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_5683c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5683c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5683c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_5683c_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_5683c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5683c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_5683c_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_5683c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
exp.setup(clustered, target = 'Cluster', session_id = 42)
# Out:
# <style type="text/css">
# #T_49ed7_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_49ed7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49ed7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_49ed7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49ed7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49ed7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_49ed7_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_49ed7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_49ed7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_49ed7_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_49ed7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         13:54:44
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_50fe0 th {
#   text-align: left;
# }
# ...

# %%
plot_model(best, plot = 'confusion_matrix')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 plot_model(best, plot = 'confusion_matrix')
#
# NameError: name 'best' is not defined

# %%
# plot_model(best, plot = 'auc')

# %%
# plot_model(best, plot = 'efficiency')
# #

# %%
evaluate_model(best)

# %%
holdout_pred = predict_model(best)

# %%
holdout_pred.head()

# %% [markdown]
# ### loading a model

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__

# %%
# functional API
# loaded_model = load_model('iforest_pipeline')
# print(loaded_model)

# OOP API
# loaded_model = s.load_model('kmeans_pipeline')
# print(loaded_model)
