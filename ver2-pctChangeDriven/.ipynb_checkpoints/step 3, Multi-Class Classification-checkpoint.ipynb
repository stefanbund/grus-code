# %% [markdown]
# ## Multi-Class Classification
#
# take clustered data, classify

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__
# Out:
# '3.0.4'

# %%
#get latest experiment in the clustered directory
import os
import glob

def newest_file(directory):
    list_of_files = glob.glob(directory + '/*')
    latest_file = max(list_of_files, key=os.path.getctime)
    return latest_file

# %%
latestEXP = newest_file("clustered")
print(latestEXP)
load_clustered = pd.read_csv(latestEXP) #'clustered/clustered_meanshift _2023-09-04 14:59:41.csv'
load_clustered
# Out:
# clustered/clustered_sc _2023-09-09 19:45:53.csv
#       Unnamed: 0  precursor_buy_cap_pct_change  precursor_ask_cap_pct_change  \
# 0              1                     -0.000443                      0.000023
# 1              2                     -0.002358                     -0.000002
# 2              3                      0.000349                      0.000031
# 3              4                      0.000473                      0.000015
# 4              5                      0.006050                      0.000020
# ...          ...                           ...                           ...
# 5627        5631                      0.000261                     -0.003409
# 5628        5632                     -0.008493                     -0.001014
# 5629        5633                     -0.002290                      0.000014
# 5630        5634                     -0.002373                     -0.000333
# 5631        5635                      0.003724                      0.000931
#
#       precursor_bid_vol_pct_change  precursor_ask_vol_pct_change  change.1  \
# 0                        -0.000184                      0.003196  0.000135
# 1                        -0.000818                     -0.000333 -0.000233
# 2                         0.000189                      0.004485 -0.000502
# 3                         0.000120                      0.001861 -0.000768
# 4                         0.002144                      0.003015 -0.000303
# ...                            ...                           ...       ...
# 5627                      0.000050                     -0.016427 -0.000398
# 5628                     -0.002097                     -0.004181 -0.283913
# 5629                     -0.000566                      0.000067  0.000399
# 5630                     -0.000586                     -0.001572  0.000000
# 5631                      0.000911                      0.004449  0.000000
#
#       surge_targets_met_pct    Cluster
# 0                 -0.033490  Cluster 0
# 1                 -0.033445  Cluster 0
# 2                 -0.033467  Cluster 0
# 3                 -0.167224  Cluster 0
# 4                 -0.371245  Cluster 0
# ...                     ...        ...
# 5627              -0.199005  Cluster 0
# 5628               0.000000  Cluster 0
# 5629               0.000000  Cluster 0
# 5630              -0.099701  Cluster 0
# 5631              -0.099800  Cluster 0
#
# [5632 rows x 8 columns]

# %%
# clustered.drop(['group', 'time', 's_MP', 'change', 'type', 'length', 'sum_change', 'surge_area' ] , axis=1, inplace=True) 
print(load_clustered.columns)
# Out:
# Index(['Unnamed: 0', 'precursor_buy_cap_pct_change',
#        'precursor_ask_cap_pct_change', 'precursor_bid_vol_pct_change',
#        'precursor_ask_vol_pct_change', 'change.1', 'surge_targets_met_pct',
#        'Cluster'],
#       dtype='object')

# %%
#eliminate surge columns, 'change', 'sum_change','surge_area',
keepable = ['precursor_buy_cap_pct_change',
       'precursor_ask_cap_pct_change', 
        'precursor_bid_vol_pct_change',
       'precursor_ask_vol_pct_change', 
        'change.1', 
        'Cluster']
clustered = load_clustered[keepable]

# %%
#setup 
from pycaret.classification import *
s = setup(clustered, target = 'Cluster', session_id = 42, normalize = True)
# Out:
# <style type="text/css">
# #T_0525e_row9_col1, #T_0525e_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0525e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0525e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0525e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0525e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0525e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_0525e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0525e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0525e_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0525e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_0525e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0525e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_0525e_row3_col1" class="data row3 col1" >Cluster 0: 0, Cluster 2: 1</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0525e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_0525e_row4_col1" class="data row4 col1" >(5632, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0525e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_0525e_row5_col1" class="data row5 col1" >(5632, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0525e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_0525e_row6_col1" class="data row6 col1" >(3942, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0525e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_0525e_row7_col1" class="data row7 col1" >(1690, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0525e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_0525e_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0525e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_0525e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0525e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_0525e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_0525e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_0525e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_0525e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_0525e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_0525e_row13_col0" class="data row13 col0" >Normalize</td>
#       <td id="T_0525e_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_0525e_row14_col0" class="data row14 col0" >Normalize method</td>
#       <td id="T_0525e_row14_col1" class="data row14 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_0525e_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_0525e_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_0525e_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_0525e_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_0525e_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_0525e_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_0525e_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_0525e_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_0525e_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_0525e_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_0525e_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_0525e_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_0525e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_0525e_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_0525e_row21_col1" class="data row21 col1" >afe1</td>
#     </tr>
#   </tbody>
# </table>

# %%
from pycaret.classification import ClassificationExperiment
exp = ClassificationExperiment()

# %%
type(exp)
# Out:
# pycaret.classification.oop.ClassificationExperiment

# %%
exp.setup(clustered, target = 'Cluster', session_id = 42)
# Out:
# <style type="text/css">
# #T_80d2e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_80d2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_80d2e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_80d2e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_80d2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_80d2e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_80d2e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_80d2e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_80d2e_row1_col1" class="data row1 col1" >Cluster</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_80d2e_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_80d2e_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_80d2e_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_80d2e_row3_col1" class="data row3 col1" >Cluster 0: 0, Cluster 2: 1</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_80d2e_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_80d2e_row4_col1" class="data row4 col1" >(5632, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_80d2e_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_80d2e_row5_col1" class="data row5 col1" >(5632, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_80d2e_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_80d2e_row6_col1" class="data row6 col1" >(3942, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_80d2e_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_80d2e_row7_col1" class="data row7 col1" >(1690, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_80d2e_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_80d2e_row8_col1" class="data row8 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_80d2e_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_80d2e_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_80d2e_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_80d2e_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_80d2e_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_80d2e_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_80d2e_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_80d2e_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_80d2e_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_80d2e_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_80d2e_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_80d2e_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_80d2e_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_80d2e_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_80d2e_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_80d2e_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_80d2e_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_80d2e_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_80d2e_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_80d2e_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_80d2e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_80d2e_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_80d2e_row19_col1" class="data row19 col1" >896d</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models()
# Out:
#                                                 \
#
# Initiated  . . . . . . . . . . . . . . . . . .
# Status     . . . . . . . . . . . . . . . . . .
# Estimator  . . . . . . . . . . . . . . . . . .
#
#
#
# Initiated                         19:46:14
# Status                    Fitting 10 Folds
# Estimator  Light Gradient Boosting Machine
# <style type="text/css">
# #T_73c8d th {
#   text-align: left;
# }
# #T_73c8d_row0_col0, #T_73c8d_row0_col1, #T_73c8d_row0_col2, #T_73c8d_row0_col3, #T_73c8d_row0_col4, #T_73c8d_row0_col5, #T_73c8d_row0_col6, #T_73c8d_row0_col7, #T_73c8d_row0_col8, #T_73c8d_row1_col0, #T_73c8d_row1_col1, #T_73c8d_row1_col2, #T_73c8d_row1_col3, #T_73c8d_row1_col4, #T_73c8d_row1_col5, #T_73c8d_row1_col6, #T_73c8d_row1_col7, #T_73c8d_row1_col8, #T_73c8d_row2_col0, #T_73c8d_row2_col1, #T_73c8d_row2_col2, #T_73c8d_row2_col3, #T_73c8d_row2_col4, #T_73c8d_row2_col5, #T_
row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_73c8d_row0_col1" class="data row0 col1" >0.9982</td>
#       <td id="T_73c8d_row0_col2" class="data row0 col2" >0.3480</td>
#       <td id="T_73c8d_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_73c8d_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_73c8d_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_73c8d_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_73c8d_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_73c8d_row0_col8" class="data row0 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_73c8d_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_73c8d_row1_col1" class="data row1 col1" >0.9982</td>
#       <td id="T_73c8d_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_73c8d_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_73c8d_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_73c8d_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_73c8d_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_73c8d_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_73c8d_row1_col8" class="data row1 col8" >0.0320</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_73c8d_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_73c8d_row2_col1" class="data row2 col1" >0.9982</td>
#       <td id="T_73c8d_row2_col2" class="data row2 col2" >0.3311</td>
#       <td id="T_73c8d_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_73c8d_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_73c8d_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_73c8d_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_73c8d_row2_col7" class="data row2 col7" >0.0000</td>
#       <td id="T_73c8d_row2_col8" class="data row2 col8" >0.2140</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_73c8d_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_73c8d_row3_col1" class="data row3 col1" >0.9982</td>
#       <td id="T_73c8d_row3_col2" class="data row3 col2" >0.4305</td>
#       <td id="T_73c8d_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_73c8d_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_73c8d_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_73c8d_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_73c8d_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_73c8d_row3_col8" class="data row3 col8" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_73c8d_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_73c8d_row4_col1" class="data row4 col1" >0.9980</td>
#       <td id="T_73c8d_row4_col2" class="data row4 col2" >0.3678</td>
#       <td id="T_73c8d_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_73c8d_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_73c8d_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_73c8d_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_73c8d_row4_col7" class="data row4 col7" >-0.0003</td>
#       <td id="T_73c8d_row4_col8" class="data row4 col8" >0.3450</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_73c8d_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_73c8d_row5_col1" class="data row5 col1" >0.9980</td>
#       <td id="T_73c8d_row5_col2" class="data row5 col2" >0.4568</td>
#       <td id="T_73c8d_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_73c8d_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_73c8d_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_73c8d_row5_col6" class="data row5 col6" >nan</td>
#       <td id="T_73c8d_row5_col7" class="data row5 col7" >-0.0003</td>
#       <td id="T_73c8d_row5_col8" class="data row5 col8" >0.1290</td>
#     </tr>
#     <tr>
#       <th id="T_73c8d_level0_row6" class="row_heading level0 row6" >et</th>
#       <td id="T_73c8d_row6_col0" class="data row6 col0" >Extra Trees Classifier</td>
#       <td id="T_73c8d_row6_col1" class="data row6 col1" >0.9980</td>
#       <td id="T_73c8d_row6_col2" class="data row6 col2" >0.3331</td>
#       <td id="T_73c8d_row6_
# Processing:   0%|          | 0/65 [00:00<?, ?it/s]

# %%
plot_model(best, plot = 'confusion_matrix')

# %%
# plot_model(best, plot = 'auc')

# %%
# plot_model(best, plot = 'efficiency')
# #

# %%
evaluate_model(best)

# %%
holdout_pred = predict_model(best)

# %%
holdout_pred.head()

# %% [markdown]
# ### loading a model

# %%
# check installed version
import pycaret
import pandas as pd
pycaret.__version__

# %%
# functional API
# loaded_model = load_model('iforest_pipeline')
# print(loaded_model)

# OOP API
# loaded_model = s.load_model('kmeans_pipeline')
# print(loaded_model)
